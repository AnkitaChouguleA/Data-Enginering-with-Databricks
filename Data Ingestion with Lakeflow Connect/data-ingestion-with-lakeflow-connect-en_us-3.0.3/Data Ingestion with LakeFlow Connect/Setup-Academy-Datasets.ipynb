# %%
# %sql
CREATE CATALOG IF NOT EXISTS dbacademy_ecommerce;

# %%
# %sql
USE CATALOG dbacademy_ecommerce;

CREATE SCHEMA IF NOT EXISTS v01;

# %%
# %sql
USE CATALOG dbacademy_ecommerce;

USE SCHEMA v01;

CREATE VOLUME IF NOT EXISTS raw;

CREATE VOLUME IF NOT EXISTS delta;
